# %% [markdown]
# Just for me to learn some different types of data structures

# %% [markdown]
# **Lists:**

# %%
# List
fruits = ["apple", "cherry", 'banana']

# %%
fruits
# Out:
# ['apple', 'cherry', 'banana']

# %%
fruits.append('kiwi')

# %%
fruits
# Out:
# ['apple', 'cherry', 'banana', 'kiwi', 'kiwi', 'kiwi']

# %%
# lists can have duplicates, while sets cannot!

# %% [markdown]
# **Dictionaries:**

# %%
fruitsDict = {
    'banana': {'colour': 'yellow'},
    'orange': {'colour': 'orange'},
    'mandarin': {'colour': 'orange', 'quantity': 12}

}

# %%
fruitsDict
# Out:
# {'banana': {'colour': 'yellow'},
#  'orange': {'colour': 'orange'},
#  'mandarin': {'colour': 'orange', 'quantity': 12}}

# %%
fruitsDict['mandarin']['quantity']
# Out:
# 12

# %%
fruitsDict.update({'colour': 'purple'})

# %%
fruitsDict
# Out:
# {'banana': {'colour': 'yellow'},
#  'orange': {'colour': 'orange'},
#  'mandarin': {'colour': 'orange', 'quantity': 12},
#  'colour': 'purple'}

# %%
fruitsDict.update({'cherry': {'colour': 'red'}})

# %%
fruitsDict
# Out:
# {'banana': {'colour': 'yellow'},
#  'orange': {'colour': 'orange'},
#  'mandarin': {'colour': 'orange', 'quantity': 12},
#  'colour': 'purple',
#  'cherry': {'colour': 'red'}}

# %%
fruitsDict.pop('colour')
# Out:
# 'purple'

# %%
fruitsDict
# Out:
# {'banana': {'colour': 'yellow'},
#  'orange': {'colour': 'orange'},
#  'mandarin': {'colour': 'orange', 'quantity': 12},
#  'cherry': {'colour': 'red'}}

# %% [markdown]
# **Sets:**

# %%
fruitSet = {'mango', 'peach', 'avocado'}

# %%
fruitSet
# Out:
# {'avocado', 'mango', 'peach'}

# %%
fruitSet.add('banana')

# %%
fruitSet
# Out:
# {'avocado', 'banana', 'mango', 'peach'}

# %%
fruitSet.add('banana')

# %%
fruitSet.remove('banana')

# %%
fruitSet
# Out:
# {'avocado', 'mango', 'peach'}

# %% [markdown]
# **Series:**

# %%
a = [1,2,3,5,8]

# %%
a
# Out:
# [1, 2, 3, 5, 8]

# %% [markdown]
# **Dataframes:**

# %%
import pandas as pd

# %%
fruitsDict
# can make it from my dictionary
# Out:
# {'banana': {'colour': 'yellow'},
#  'orange': {'colour': 'orange'},
#  'mandarin': {'colour': 'orange', 'quantity': 12},
#  'cherry': {'colour': 'red'}}

# %%
fruitsDF = pd.DataFrame(data=fruitsDict)

# %%
fruitsDF
# Out:
#           banana  orange mandarin cherry
# colour    yellow  orange   orange    red
# quantity     NaN     NaN       12    NaN

# %%
2
# Out:
# 2
